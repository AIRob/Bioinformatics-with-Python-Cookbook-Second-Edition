# %%
import os
import random
import shutil
import sys

import dendropy
from dendropy.interop import raxml

# %%
ebola_data = dendropy.DnaCharacterMatrix.get_from_path('trim.fasta', 'fasta')
rx = raxml.RaxmlRunner()
ebola_tree = rx.estimate_tree(ebola_data, ['-m', 'GTRGAMMA', '-N', '10'])
print('RAxML temporary directory: %s' % rx.working_dir_path)
del ebola_data
# Out:
# RAxML temporary directory: /tmp/tmpxkrxjx38

# %%
ebola_tree.write_to_path('my_ebola.nex', 'nexus')

# %%
import matplotlib.pyplot as plt
from Bio import Phylo
# %matplotlib inline
my_ebola_tree = Phylo.read('my_ebola.nex', 'nexus')
my_ebola_tree.name = 'Our Ebolavirus tree'

fig = plt.figure(figsize=(16, 18))
ax = fig.add_subplot(1, 1, 1)
Phylo.draw(my_ebola_tree, axes=ax)

# %% [markdown]
# ## RAxML with Biopython

# %%
# XXX change
from Bio.Phylo.Applications import RaxmlCommandline
raxml_cline = RaxmlCommandline(sequences='trim.fasta',
                               model='GTRGAMMA', name='biopython',
                               num_replicates='10',
                               parsimony_seed=random.randint(0, sys.maxsize),
                               working_dir=os.getcwd() + os.sep + 'bp_rx')
print(raxml_cline)
try:
    os.mkdir('bp_rx')
except OSError:
    shutil.rmtree('bp_rx')
    os.mkdir('bp_rx')
out, err = raxml_cline()
# Out:
# raxmlHPC -m GTRGAMMA -n biopython -p 2236485020667767809 -s trim.fasta -w /home/tiago_antao/bioinf-python-2/notebooks/05_Phylo/bp_rx -N 10

# %%
from Bio import Phylo
biopython_tree = Phylo.read('bp_rx/RAxML_bestTree.biopython', 'newick')

# %%
print(biopython_tree)
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade(branch_length=0.0)
#         Clade(branch_length=1.00000050002909e-06)
#             Clade(branch_length=0.00010363906582039957, name='BDBV_KC545395')
#             Clade(branch_length=0.00015505048059902412)
#                 Clade(branch_length=0.00010409820095316519, name='BDBV_KC545396')
#                 Clade(branch_length=0.005793960959347468)
#                     Clade(branch_length=0.006922882569609149, name='BDBV_FJ217161')
#                     Clade(branch_length=0.3891501198983821)
#                         Clade(branch_length=0.4253496968022101, name='TAFV_FJ217162')
#                         Clade(branch_length=0.40065935721085355)
#                             Clade(branch_length=0.5085134001424478)
#                                 Clade(branch_length=0.006928886241223774)
#                                     Clade(branch_length=0.005347055632969207)
#                                         Clade(branch_length=0.006923680323020659)
#                                             Clade(branch_length=5.158054489925915e-05, name='EBOV_1995_KC242796')
#                                             Clade(branch_length=1.00000050002909e-06, name='EBOV_1995_KC242799')
#                                         Clade(branch_length=0.004453033785341781)
#                                             Clade(branch_length=4.632153601964531e-05, name='EBOV_1976_KC242801')
#                                             Clade(branch_length=0.0005219631958053222, name='EBOV_1976_AF272001')
#                                     Clade(branch_length=0.008852206822472923)
#                                         Clade(branch_length=1.00000050002909e-06)
#                                             Clade(branch_length=5.164643824099361e-05)
#                                                 Clade(branch_length=0.00041338054783292586, name='EBOV_2007_KC242788')
#                                                 Clade(branch_length=1.00000050002909e-06, name='EBOV_2007_KC242787')
#                                             Clade(branch_length=1.00000050002909e-06)
#                                                 Clade(branch_length=0.0002066377555838748, name='EBOV_2007_KC242784')
#                                                 Clade(branch_length=5.165821542223576e-05)
#                                                     Clade(branch_length=5.164604221520126e-05, name='EBOV_2007_KC242786')
#                                                     Clade(branch_length=0.00010331178465755738, name='EBOV_2007_KC242789')
#                                         Clade(branch_length=5.159560332975403e-05)
#                                             Clade(branch_length=0.00020670965697952362, name='EBOV_2007_KC242790')
#                                             Clade(branch_length=0.00015500958987135015, name='EBOV_2007_KC242785')
#                                 Clade(branch_length=0.01272591554888021)
#                                     Clade(branch_length=1.00000050002909e-06)
#                                         Clade(branch_length=1.00000050002909e-06)
#                                             Clade(branch_length=1.00000050002909e-06)
#                                                 Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034554')
#                                                 Clade(branch_length=1.00000050002909e-06)
#                                                     Clade(branch_length=1.00000050002909e-06)
#                                                         Clade(branch_length=1.00000050002909e-06)
#                                                             Clade(branch_length=5.161948379294921e-05, name='EBOV_2014_KM034561')
#                                                             Clade(branch_length=0.00010321455862317519, name='EBOV_2014_KM034562')
#                                                         Clade(branch_length=1.00000050002909e-06)
#                                                             Clade(branch_length=5.160122395906718e-05, name='EBOV_2014_KM034559')
#                                                             Clade(branch_length=0.00020646478338946078)
#                                                                 Clade(branch_length=0.00010320693313076045)
#                                                                     Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034551')
#                                                                     Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034558')
#                                                                 Clade(branch_length=1.00000050002909e-06)
#                                                                     Clade(branch_length=1.00000050002909e-06)
#                                                                         Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034557')
#                                                                         Clade(branch_length=1.00000050002909e-06)
#                                                                             Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034556')
#                                                                             Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034560')
#                                                                     Clade(branch_length=1.00000050002909e-06)
#                                                                         Clade(branch_length=0.00010321876900645744, name='EBOV_2014_KM034553')
#                                                                         Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034552')
#                                                     Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034555')
#                                             Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034550')
#                                         Clade(branch_length=1.00000050002909e-06, name='EBOV_2014_KM034549')
#                                     Clade(branch_length=5.322732436654093e-05, name='EBOV_2014_KM034563')
#                             Clade(branch_length=0.3651408230635145)
#                                 Clade(branch_length=0.940599692855016)
#                                     Clade(branch_length=0.017785969865843805)
#                                         Clade(branch_length=0.00237021890521127, name='SUDV_EU338380')
#                                         Clade(branch_length=7.97522110555951e-05)
#                                             Clade(branch_length=0.0008538661086532939, name='SUDV_FJ968794')
#                                             Clade(branch_length=0.001163935697155799, name='SUDV_KC242783')
#                                     Clade(branch_length=0.0298990764146889)
#                                         Clade(branch_length=0.0015143877912633596)
#                                             Clade(branch_length=0.002447224359863818, name='SUDV_AY729654')
#                                             Clade(branch_length=0.0034268804999680407, name='SUDV_JN638998')
#                                         Clade(branch_length=0.004030237631762224, name='SUDV_KC589025')
#                                 Clade(branch_length=0.8525602583424724)
#                                     Clade(branch_length=0.018164440611231493, name='RESTV_FJ621584')
#                                     Clade(branch_length=0.011790470106145493)
#                                         Clade(branch_length=0.016896785217157474)
#                                             Clade(branch_length=0.0006361895626815918, name='RESTV_JX477165')
#                                             Clade(branch_length=0.00015522042978438074, name='RESTV_FJ621583')
#                                         Clade(branch_length=0.003908356361637118)
#                                             Clade(branch_length=0.0017484593474139424)
#                                                 Clade(branch_length=0.0003160248200595299, name='RESTV_JX477166')
#                                                 Clade(branch_length=0.0006343144992401877, name='RESTV_AB050936')
#                                             Clade(branch_length=0.01082746129450388, name='RESTV_FJ621585')
#         Clade(branch_length=0.00015555813989479736, name='BDBV_KC545394')
#         Clade(branch_length=0.00010363234968308986, name='BDBV_KC545393')
